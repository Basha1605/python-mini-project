# %%
import random

# %%
a1=[]
a2=[]
a3=[]
a4=[]
a5=[]

# %%
for _ in range(1000):
     a1.append(random.randint(0,100))
     a2.append(random.randint(50,70))
     a3.append(random.randint(10,20))
     a4.append(random.randint(5,10))
     a5.append(random.randint(20,80))

# %%
df ={
     'grade' : a1,
      'weight' : a2,
      'friends' : a3,
      'cousins' : a4,
      'projects' : a5
    }

# %%
df
# Out:
# {'grade': [98,
#   77,
#   58,
#   22,
#   90,
#   94,
#   88,
#   84,
#   23,
#   1,
#   53,
#   93,
#   30,
#   2,
#   39,
#   32,
#   82,
#   37,
#   82,
#   42,
#   94,
#   60,
#   82,
#   55,
#   76,
#   41,
#   24,
#   48,
#   34,
#   14,
#   82,
#   14,
#   23,
#   94,
#   77,
#   95,
#   15,
#   66,
#   6,
#   59,
#   37,
#   57,
#   67,
#   7,
#   50,
#   20,
#   32,
#   3,
#   48,
#   63,
#   83,
#   27,
#   34,
#   48,
#   65,
#   99,
#   14,
#   45,
#   23,
#   81,
#   77,
#   30,
#   33,
#   14,
#   60,
#   34,
#   84,
#   11,
#   53,
#   38,
#   56,
#   69,
#   46,
#   86,
#   40,
#   14,
#   12,
#   14,
#   98,
#   71,
#   96,
#   1,
#   4,
#   50,
#   95,
#   60,
#   77,
#   46,
#   85,
#   10,
#   99,
#   15,
#   22,
#   41,
#   56,
#   82,
#   55,
#   22,
#   51,
#   32,
#   3,
#   17,
#   88,
#   53,
#   45,
#   0,
#   37,
#   12,
#   100,
#   41,
#   61,
#   7,
#   0,
#   97,
#   0,
#   89,
#   79,
#   59,
#   76,
#   69,
#   7,
#   58,
#   21,
#   41,
#   21,
# ...

# %%
import pandas as pd

# %%
df1 = pd.DataFrame(df)

# %%
df1
# Out:
#      grade  weight  friends  cousins  projects
# 0       98      60       11        7        37
# 1       77      54       20        7        24
# 2       58      50       16       10        27
# 3       22      53       12       10        38
# 4       90      56       13        9        48
# ..     ...     ...      ...      ...       ...
# 995     52      59       20        5        78
# 996     15      60       18        5        49
# 997     63      67       12        6        80
# 998      3      52       16        7        66
# 999     97      60       13        5        53
#
# [1000 rows x 5 columns]

# %%
df1.to_csv('/Feb6TestData.csv')

# %%
df1['grade'].count()
# Out:
# 1000

# %%
df1['grade'].count
# Out:
# <bound method Series.count of 0      98
# 1      77
# 2      58
# 3      22
# 4      90
#        ..
# 995    52
# 996    15
# 997    63
# 998     3
# 999    97
# Name: grade, Length: 1000, dtype: int64>

# %%
friend15 = df1[ 'friends']>15

# %%
df1[friend15]
# Out:
#      grade  weight  friends  cousins  projects
# 1       77      54       20        7        24
# 2       58      50       16       10        27
# 6       88      53       16        8        70
# 8       23      54       20        7        28
# 10      53      68       17        5        54
# ..     ...     ...      ...      ...       ...
# 986     11      57       18        9        39
# 987     19      67       19        7        23
# 995     52      59       20        5        78
# 996     15      60       18        5        49
# 998      3      52       16        7        66
#
# [428 rows x 5 columns]

# %%
grade50 = df1['grade']>50

# %%
df1[grade50]
# Out:
#      grade  weight  friends  cousins  projects
# 0       98      60       11        7        37
# 1       77      54       20        7        24
# 2       58      50       16       10        27
# 4       90      56       13        9        48
# 5       94      67       11        5        70
# ..     ...     ...      ...      ...       ...
# 985     68      66       18       10        48
# 992    100      59       15        5        40
# 995     52      59       20        5        78
# 997     63      67       12        6        80
# 999     97      60       13        5        53
#
# [482 rows x 5 columns]

# %%
friend15 = df1['friends'] > 15

# %%
friend15
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 995     True
# 996     True
# 997    False
# 998     True
# 999    False
# Name: friends, Length: 1000, dtype: bool

# %%
friend18 = df1['friends'] > 18

# %%
friend18
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997    False
# 998    False
# 999    False
# Name: friends, Length: 1000, dtype: bool

# %%
grade50 = df1['grade']>50

# %%
df1[grade50]
# Out:
#      grade  weight  friends  cousins  projects
# 0       98      60       11        7        37
# 1       77      54       20        7        24
# 2       58      50       16       10        27
# 4       90      56       13        9        48
# 5       94      67       11        5        70
# ..     ...     ...      ...      ...       ...
# 985     68      66       18       10        48
# 992    100      59       15        5        40
# 995     52      59       20        5        78
# 997     63      67       12        6        80
# 999     97      60       13        5        53
#
# [482 rows x 5 columns]

# %%
grade75 = df1['grade'] > 75

# %%
grade75
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4       True
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999     True
# Name: grade, Length: 1000, dtype: bool

# %%
grade98  = df1['grade'] > 98

# %%
df1[grade98]
# Out:
#      grade  weight  friends  cousins  projects
# 55      99      54       19        9        64
# 90      99      67       10        9        47
# 108    100      59       14        5        35
# 139     99      63       13       10        63
# 379     99      61       16        9        69
# 409     99      61       17        5        43
# 532     99      66       19        5        62
# 613    100      61       13        8        23
# 614     99      67       19        9        66
# 742     99      57       16        5        32
# 785     99      69       18       10        76
# 860     99      66       17        8        67
# 876    100      66       16        9        24
# 992    100      59       15        5        40

# %%
df1[friend18 & grade98]['friends']
# Out:
# 55     19
# 532    19
# 614    19
# Name: friends, dtype: int64

# %%
df1[friend15 & grade75].plot()
# Out:
# <Axes: >

# %%
df1[friend18 & grade98].plot(x = 'grade',y = 'projects',kind = 'box')
# Out:
# <Axes: >

# %%
df1[friend15 & grade75].plot(x = 'grade',y = 'projects', kind = 'scatter')
# Out:
# <Axes: xlabel='grade', ylabel='projects'>

# %%
df1[friend15 & grade75].plot(x = 'grade',y = 'projects', kind = 'bar')
# Out:
# <Axes: xlabel='grade'>

# %%
df1[friend15 & grade75].plot(x = 'grade',y = 'projects', kind = 'scatter', title = 'Sample Graph')
# Out:
# <Axes: title={'center': 'Sample Graph'}, xlabel='grade', ylabel='projects'>

# %%
from matplotlib import pyplot as plt

# %%
df1[friend15 & grade75].plot(x = 'grade',y = 'projects', kind = 'scatter', title = 'Sample Graph')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.legend('Test Data')
plt.show()
